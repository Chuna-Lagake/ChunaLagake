# %%
import os, csv, zipfile, json
import pandas as pd
from lightfm import LightFM
from itertools import islice
# Out:
# c:\users\mahes\appdata\local\programs\python\python37\lib\site-packages\lightfm\_lightfm_fast.py:9: UserWarning: LightFM was compiled without OpenMP support. Only a single thread will be used.
#   warnings.warn('LightFM was compiled without OpenMP support. '

# %%
def get_data():
    return(
        csv.DictReader(
        (x for x in open('data/User-Features.csv')), delimiter = ","
        ),
        csv.DictReader(
        (x for x in open('data/Item-Features.csv')), delimiter = ","
        ),
        csv.DictReader(
        (x for x in open('data/Ratings.csv')), delimiter = ","
        )
    )

def get_user_data():
    return get_data()[0]

def get_item_data():
    return get_data()[1]

def get_ratings():
    return get_data()[2]

# %%
print(csv.DictReader(x for x in open('data/Ratings.csv')))

# %%
user_features, item_features, ratings = get_data()

# %% [markdown]
# # Visualize the Dataset

# %%
print("_______________________USER FEATURES_________________________")
for line in islice(user_features, 3):
    print(json.dumps(line, indent = 4))
    print("_____________________________")
    
print("______________________ITEM FEATURES_________________________")
for line in islice(item_features, 3):
    print(json.dumps(line, indent = 4))
    print("___________________________")
    
print("__________________________RATINGS____________________________")
for line in islice(ratings, 3):
    print(json.dumps(line, indent = 4))
    print("_____________________________")
# Out:
# _______________________USER FEATURES_________________________
# {
#     "User_ID": "0",
#     "Age": "18"
# }
# _____________________________
# {
#     "User_ID": "1",
#     "Age": "18"
# }
# _____________________________
# {
#     "User_ID": "2",
#     "Age": "18"
# }
# _____________________________
# ______________________ITEM FEATURES_________________________
# {
#     "Item_ID": "1",
#     "Names": "Banaras Sada Paan",
#     "Banaras": "1.0",
#     "Calcutta": "",
#     "Maghai": "",
#     "Sada": "1.0",
#     "Meetha": "",
#     "Chocolate": "",
#     "Dry Fruit": "",
#     "Mango": "",
#     "Strawberry": "",
#     "Pineapple": "",
#     "Gold": "",
#     "Kaju": "",
#     "Jelly": "",
#     "Rose": "",
#     "Shahi": "",
#     "Kesar": "",
#     "Vanilla": "",
#     "Masala": "1.0",
#     "Khatta": "1.0",
#     "Orange": "",
#     "White": "",
#     "Silver": "",
#     "RaatRani": "",
#     "Nutella": "",
#     "Special": ""
# }
# ___________________________
# {
#     "Item_ID": "2",
#     "Names": "Calcutta Sada Paan",
#     "Banaras": "",
#     "Calcutta": "1.0",
#     "Maghai": "",
#     "Sada": "1.0",
#     "Meetha": "",
#     "Chocolate": "",
#     "Dry Fruit": "",
#     "Mango": "",
#     "Strawberry": "",
#     "Pineapple": "",
#     "Gold": "",
#     "Kaju": "",
#     "Jelly": "",
#     "Rose": "",
#     "Shahi": "",
#     "Kesar": "",
#     "Vanilla": "",
#     "Masala": "1.0",
#     "Khatta": "1.0",
#     "Orange": "",
#     "White": "",
#     "Silver": "",
#     "RaatRani": "",
#     "Nutella": "",
#     "Special": ""
# }
# ___________________________
# {
#     "Item_ID": "3",
#     "Names": "Banaras Meetha Paan",
#     "Banaras": "1.0",
#     "Calcutta": "",
#     "Maghai": "",
#     "Sada": "",
#     "Meetha": "1.0",
#     "Chocolate": "",
#     "Dry Fruit": "",
#     "Mango": "",
#     "Strawberry": "",
#     "Pineapple": "",
#     "Gold": "",
#     "Kaju": "",
#     "Jelly": "",
#     "Rose": "",
#     "Shahi": "",
#     "Kesar": "",
#     "Vanilla": "",
#     "Masala": "",
#     "Khatta": "",
#     "Orange": "",
#     "White": "",
#     "Silver": "",
#     "RaatRani": "",
#     "Nutella": "",
#     "Special": ""
# }
# ___________________________
# __________________________RATINGS____________________________
# {
#     "User_ID": "0",
#     "Ratings": "3.0",
#     "Item_Name": "Banaras Sada Paan",
#     "Item_ID": "1"
# }
# _____________________________
# {
#     "User_ID": "0",
#     "Ratings": "3.0",
#     "Item_Name": "Maghai Meetha Paan",
#     "Item_ID": "5"
# }
# _____________________________
# {
#     "User_ID": "0",
#     "Ratings": "5.0",
#     "Item_Name": "Maghai Chocolate Paan",
#     "Item_ID": "7"
# }
# _____________________________

# %%
import pandas as pd
df = pd.read_csv('data/Item-Features.csv')

# item_features = []
# for i in df.columns:
#     if i != 'Item_ID' and i != 'Names':
#         item_features.append(i)
df
# Out:
#     Item_ID                              Names  Banaras  Calcutta  Maghai  \
# 0         1                  Banaras Sada Paan      1.0       NaN     NaN
# 1         2                 Calcutta Sada Paan      NaN       1.0     NaN
# 2         3                Banaras Meetha Paan      1.0       NaN     NaN
# 3         4               Calcutta Meetha Paan      NaN       1.0     NaN
# 4         5                 Maghai Meetha Paan      NaN       NaN     1.0
# 5         6            Calcutta Chocolate Paan      NaN       1.0     NaN
# 6         7              Maghai Chocolate Paan      NaN       NaN     1.0
# 7         8            Calcutta Dry Fruit Paan      NaN       1.0     NaN
# 8         9              Maghai Dry Fruit Paan      NaN       NaN     1.0
# 9        10                Calcutta Mango Paan      NaN       1.0     NaN
# 10       11                  Maghai Mango Paan      NaN       NaN     1.0
# 11       12           Calcutta Strawberry Paan      NaN       1.0     NaN
# 12       13             Maghai Strawberry Paan      NaN       NaN     1.0
# 13       14            Calcutta Pineapple Paan      NaN       1.0     NaN
# 14       15              Maghai Pineapple Paan      NaN       NaN     1.0
# 15       16                 Calcutta Gold Paan      NaN       1.0     NaN
# 16       17                   Maghai Gold Paan      NaN       NaN     1.0
# 17       18                 Calcutta Kaju Paan      NaN       1.0     NaN
# 18       19                   Maghai Kaju Paan      NaN       NaN     1.0
# 19       20                Calcutta Jelly Paan      NaN       1.0     NaN
# 20       21                  Maghai Jelly Paan      NaN       NaN     1.0
# 21       22                 Calcutta Rose Paan      NaN       1.0     NaN
# 22       23                   Maghai Rose Paan      NaN       NaN     1.0
# 23       24                Calcutta Shahi Paan      NaN       1.0     NaN
# 24       25                  Maghai Shahi Paan      NaN       NaN     1.0
# 25       26     Calcutta Golden Chocolate Paan      NaN       1.0     NaN
# 26       27       Maghai Golden Chocolate Paan      NaN       NaN     1.0
# 27       28                Calcutta Kesar Paan      NaN       1.0     NaN
# 28       29                  Maghai Kesar Paan      NaN       NaN     1.0
# 29       30    Calcutta Vanilla Chocolate Paan      NaN       1.0     NaN
# 30       31      Maghai Vanilla Chocolate Paan      NaN       NaN     1.0
# 31       32      Calcutta Shahi Chocolate Paan      NaN       1.0     NaN
# 32       33        Maghai Shahi Chocolate Paan      NaN       NaN     1.0
# 33       34               Calcutta Masala Paan      NaN       1.0     NaN
# 34       35                 Maghai Masala Paan      NaN       NaN     1.0
# 35       36        Calcutta Silver Masala Paan      NaN       1.0     NaN
# 36       37          Maghai Silver Masala Paan      NaN       NaN     1.0
# 37       38        Calcutta Khatta Meetha Paan      NaN       1.0     NaN
# 38       39          Maghai Khatta Meetha Paan      NaN       NaN     1.0
# 39       40      Calcutta White Chocolate Paan      NaN       1.0     NaN
# 40       41        Maghai White Chocolate Paan      NaN       NaN     1.0
# 41       42             Calcutta RaatRani Paan      NaN       1.0     NaN
# 42       43               Maghai RaatRani Paan      NaN       NaN     1.0
# 43       44               Calcutta Orange Paan      NaN       1.0     NaN
# 44       45                 Maghai Orange Paan      NaN       NaN     1.0
# 45       46              Calcutta Nutella Paan      NaN       1.0     NaN
# 46       47                Maghai Nutella Paan      NaN       NaN     1.0
# 47       48  Calcutta ChunaLagake Special Paan      NaN       1.0     NaN
# 48       49    Maghai ChunaLagake Special Paan      NaN       NaN     1.0
# 49       50          Special Shahi Golden Paan      NaN       NaN     NaN
#
#     Sada  Meetha  Chocolate  Dry Fruit  Mango  ...  Kesar  Vanilla  Masala  \
# 0    1.0     NaN        NaN        NaN    NaN  ...    NaN      NaN     1.0
# 1    1.0     NaN        NaN        NaN    NaN  ...    NaN      NaN     1.0
# 2    NaN     1.0        NaN        NaN    NaN  ...    NaN      NaN     NaN
# 3    NaN     1.0        NaN        NaN    NaN  ...    NaN      NaN     NaN
# 4    NaN     1.0        NaN        NaN    NaN  ...    NaN      NaN     NaN
# 5    NaN     1.0        1.0        NaN    NaN  ...    NaN      NaN     NaN
# 6    NaN     1.0        1.0        NaN    NaN  ...    NaN      NaN     NaN
# 7    1.0     NaN        NaN        1.0    NaN  ...    NaN      NaN     NaN
# 8    1.0     NaN        NaN        1.0    NaN  ...    NaN      NaN     NaN
# 9    NaN     1.0        NaN        NaN    1.0  ...    NaN      NaN     NaN
# 10   NaN     1.0        NaN        NaN    1.0  ...    NaN      NaN     NaN
# 11   NaN     1.0        NaN        NaN    NaN  ...    NaN      NaN     NaN
# 12   NaN     1.0        NaN        NaN    NaN  ...    NaN      NaN     NaN
# 13   NaN     1.0        NaN        NaN    NaN  ...    NaN      NaN     NaN
# 14   NaN     1.0        NaN        NaN    NaN  ...    NaN      NaN     NaN
# 15   1.0     NaN        NaN        NaN    NaN  ...    NaN      NaN     NaN
# 16   1.0     NaN        NaN        NaN    NaN  ...    NaN      NaN     NaN
# 17   1.0     NaN        NaN        1.0    NaN  ...    NaN      NaN     NaN
# 18   1.0     NaN        NaN        1.0    NaN  ...    NaN      NaN     NaN
# 19   NaN     1.0        NaN        NaN    NaN  ...    NaN      NaN     NaN
# 20   NaN     1.0        NaN        NaN    NaN  ...    NaN      NaN     NaN
# 21   1.0     NaN        NaN        NaN    NaN  ...    NaN      NaN     NaN
# 22   1.0     NaN        NaN        NaN    NaN  ...    NaN      NaN     NaN
# 23   1.0     NaN        NaN        1.0    NaN  ...    1.0      NaN     1.0
# 24   1.0     NaN        NaN        1.0    NaN  ...    1.0      NaN     1.0
# 25   NaN     1.0        1.0        NaN    NaN  ...    1.0      NaN     NaN
# 26   NaN     1.0        1.0        NaN    NaN  ...    1.0      NaN     NaN
# 27   1.0     NaN        NaN        1.0    NaN  ...    1.0      NaN     NaN
# 28   1.0     NaN        NaN        1.0    NaN  ...    1.0      NaN     NaN
# 29   NaN     1.0        1.0        NaN    NaN  ...    NaN      NaN     NaN
# 30   NaN     1.0        1.0        NaN    NaN  ...    NaN      NaN     NaN
# 31   NaN     1.0        1.0        1.0    NaN  ...    1.0      NaN     NaN
# 32   NaN     1.0        1.0        1.0    NaN  ...    1.0      NaN     NaN
# 33   NaN     NaN        NaN        NaN    NaN  ...    NaN      NaN     1.0
# 34   NaN     NaN        NaN        NaN    NaN  ...    NaN      NaN     1.0
# 35   NaN     NaN        NaN        NaN    NaN  ...    NaN      NaN     1.0
# 36   NaN     NaN        NaN        NaN    NaN  ...    NaN      NaN     1.0
# 37   NaN     1.0        NaN        NaN    NaN  ...    NaN      NaN     1.0
# 38   NaN     1.0        NaN        NaN    NaN  ...    NaN      NaN     1.0
# 39   NaN     1.0        1.0        NaN    NaN  ...    NaN      NaN     NaN
# 40   NaN     1.0        1.0        NaN    NaN  ...    NaN      NaN     NaN
# 41   NaN     NaN        NaN        NaN    NaN  ...    NaN      NaN     1.0
# 42   NaN     NaN        NaN        NaN    NaN  ...    NaN      NaN     1.0
# 43   NaN     1.0        NaN        NaN    NaN  ...    NaN      NaN     NaN
# 44   NaN     1.0        NaN        NaN    NaN  ...    NaN      NaN     NaN
# 45   NaN     1.0        NaN        NaN    NaN  ...    NaN      NaN     NaN
# 46   NaN     1.0        NaN        NaN    NaN  ...    NaN      NaN     NaN
# 47   NaN     NaN        NaN        1.0    NaN  ...    1.0      NaN     1.0
# 48   NaN     NaN        NaN        1.0    NaN  ...    1.0      NaN     1.0
# 49   NaN     NaN        NaN        1.0    NaN  ...    1.0      NaN     1.0
#
#     Khatta  Orange  White  Silver  RaatRani  Nutella  Special
# 0      1.0     NaN    NaN     NaN       NaN      NaN      NaN
# 1      1.0     NaN    NaN     NaN       NaN      NaN      NaN
# 2      NaN     NaN    NaN     NaN       NaN      NaN      NaN
# 3      NaN     NaN    NaN     NaN       NaN      NaN      NaN
# 4      NaN     NaN    NaN     NaN       NaN      NaN      NaN
# 5      NaN     NaN    NaN     NaN       NaN      NaN      NaN
# 6      NaN     NaN    NaN     NaN       NaN      NaN      NaN
# 7      NaN     NaN    NaN     NaN       NaN      NaN      NaN
# 8      NaN     NaN    NaN     NaN       NaN      NaN      NaN
# 9      NaN     NaN    NaN     NaN       NaN      NaN      NaN
# 10     NaN     NaN    NaN     NaN       NaN      NaN      NaN
# 11     NaN     NaN    NaN     NaN       NaN      NaN      NaN
# 12     NaN     NaN    NaN     NaN       NaN      NaN      NaN
# 13     NaN     NaN    NaN     NaN       NaN      NaN      NaN
# 14     NaN     NaN    NaN     NaN       NaN      NaN      NaN
# 15     NaN     NaN    NaN     NaN       NaN      NaN      NaN
# 16     1.0     NaN    NaN     NaN       NaN      NaN      NaN
# 17     NaN     NaN    NaN     NaN       NaN      NaN      NaN
# 18     NaN     NaN    NaN     NaN       NaN      NaN      NaN
# 19     NaN     NaN    NaN     NaN       NaN      NaN      NaN
# 20     NaN     NaN    NaN     NaN       NaN      NaN      NaN
# 21     NaN     NaN    NaN     NaN       NaN      NaN      NaN
# 22     NaN     NaN    NaN     NaN       NaN      NaN      NaN
# 23     1.0     NaN    NaN     NaN       NaN      NaN      NaN
# 24     1.0     NaN    NaN     NaN       NaN      NaN      NaN
# 25     NaN     NaN    NaN     NaN       NaN      NaN      NaN
# 26     NaN     NaN    NaN     NaN       NaN      NaN      NaN
# 27     NaN     NaN    NaN     NaN       NaN      NaN      NaN
# 28     NaN     NaN    NaN     NaN       NaN      NaN      NaN
# 29     NaN     NaN    NaN     NaN       NaN      NaN      NaN
# 30     NaN     NaN    NaN     NaN       NaN      NaN      NaN
# 31     1.0     NaN    NaN     NaN       NaN      NaN      NaN
# 32     1.0     NaN    NaN     NaN       NaN      NaN      NaN
# 33     1.0     NaN    NaN     NaN       NaN      NaN      NaN
# 34     1.0     NaN    NaN     NaN       NaN      NaN      NaN
# 35     1.0     NaN    NaN     1.0       NaN      NaN      NaN
# 36     1.0     NaN    NaN     1.0       NaN      NaN      NaN
# 37     1.0     NaN    NaN     NaN       NaN      NaN      NaN
# 38     1.0     NaN    NaN     NaN       NaN      NaN      NaN
# 39     NaN     NaN    NaN     NaN       NaN      NaN      NaN
# 40     NaN     NaN    NaN     NaN       NaN      NaN      NaN
# 41     NaN     NaN    NaN     NaN       1.0      NaN      NaN
# 42     NaN     NaN    NaN     NaN       1.0      NaN      NaN
# 43     NaN     NaN    NaN     NaN       NaN      NaN      NaN
# 44     NaN     NaN    NaN     NaN       NaN      NaN      NaN
# 45     NaN     NaN    NaN     NaN       NaN      1.0      NaN
# 46     NaN     NaN    NaN     NaN       NaN      1.0      NaN
# 47     1.0     NaN    NaN     NaN       NaN      NaN      1.0
# 48     1.0     NaN    NaN     NaN       NaN      NaN      1.0
# 49     1.0     NaN    NaN     NaN       NaN      NaN      1.0
#
# [50 rows x 27 columns]

# %% [markdown]
# # BUILD ID MAPPINGS

# %%
# create a dataset
from lightfm import LightFM
from lightfm.data import Dataset

dataset = Dataset()

dataset.fit((x['User_ID'] for x in get_ratings()),
           (x['Item_ID'] for x in get_ratings()))

# %%
num_users, num_items = dataset.interactions_shape()
print("Num Users: {}, Num Items: {}".format(num_users, num_items))
# Out:
# Num Users: 15, Num Items: 50

# %%
dataset.fit_partial(items=(x['Item_ID'] for x in get_item_data()),
                    users = (x['User_ID'] for x in get_user_data()),
                    item_features=(x['Calcutta'] for x in get_item_data()),
                    user_features=(x['Age'] for x in get_user_data()))

# %%
dataset.fit_partial(items = (x['Item_ID'] for x in get_item_data()),
                   item_features = (x['Banaras'] for x in get_item_data()))

# %%
dataset.fit_partial(users = (x['User_ID'] for x in get_user_data()),
                   user_features=(x['Age'] for x in get_user_data()))

# %% [markdown]
# # BUILD INTERACTIONS

# %%
(interactions, weights) = dataset.build_interactions(((x['User_ID'], x['Item_ID']) for x in get_ratings()))
print(repr(interactions))
# Out:
# <17x50 sparse matrix of type '<class 'numpy.int32'>'
# 	with 250 stored elements in COOrdinate format>

# %%
item_features = dataset.build_item_features(((x['Item_ID'], [x['Calcutta'], x['Banaras']])
                                              for x in get_item_data()))

# %%
user_features = dataset.build_user_features(((x['User_ID'], [x['Age']])
                                              for x in get_user_data()))

# %%
from lightfm import LightFM
from lightfm.cross_validation import random_train_test_split



model = LightFM(loss='warp')
model.fit(interactions, item_features=item_features, user_features=user_features)

# %%
import numpy as np

labels = np.array([x['Item_ID'] for x in get_ratings()])
labels.shape
# Out:
# (250,)

# %%
positives = []
recommended = []
def sample_recommendation(model, data, user_ids):
    n_users, n_items = data.shape
    for user_id in user_ids:
        known_positives = labels[data.tocsr()[user_id].indices]
        
        scores = model.predict(user_id, np.arange(n_items))
        
        top_items = labels[np.argsort(-scores)]
        
        print("USER ID: {}".format(user_id))
        print("   Known Positives:")
        
        for x in known_positives[:3]:
            positives.append(x)
            print("      {}".format(x))
            
        print("   Recommmended:")
        
        for x in top_items[:3]:
            recommended.append(x)
            print("      {}".format(x))
            
        positives.append(user_id)
        recommended.append(user_id)
    return positives, recommended

# %%
sample_recommendation(model, interactions, [1, 3, 4])
# Out:
# USER ID: 1
#    Known Positives:
#       1
#       7
#       1
#    Recommmended:
#       1
#       7
#       2
# USER ID: 3
#    Known Positives:
#       1
#       5
#       7
#    Recommmended:
#       7
#       1
#       2
# USER ID: 4
#    Known Positives:
#       1
#       46
#    Recommmended:
#       1
#       7
#       2
# (['1', '7', '1', 1, '1', '5', '7', 3, '1', '46', 4],
#  ['1', '7', '2', 1, '7', '1', '2', 3, '1', '7', '2', 4])
